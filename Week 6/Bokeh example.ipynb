# %%
from bokeh.charts import Histogram
from bokeh.sampledata.autompg import autompg as df
from bokeh.charts import defaults, vplot, hplot, show, output_file
from bokeh.models.layouts import Row, Column
from bokeh.io import output_notebook

# %%
defaults.width = 450
defaults.height = 350

# input options
hist = Histogram(df['mpg'], title="df['mpg']")
hist2 = Histogram(df, 'displ', title="df, 'displ'")
hist3 = Histogram(df, values='hp', title="df, values='hp'")

hist4 = Histogram(df, values='hp', color='cyl',
                  title="df, values='hp', color='cyl'", legend='top_right')

hist5 = Histogram(df, values='mpg', bins=50,
                  title="df, values='mpg', bins=50")

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="82911a0f-3fca-4841-8f6a-9b865ee09c3f">Loading BokehJS ...</span>
#     </div>

# %%
show(
    Column(
        Row(hist, hist2, hist3),
        Row(hist4, hist5)
    )
)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="135973c5-a03f-47b4-8cf2-ed7a8e132e95"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("135973c5-a03f-47b4-8cf2-ed7a8e132e95");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '135973c5-a03f-47b4-8cf2-ed7a8e132e95' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"1fcdf1a3-b34f-49b6-a07f-f68053138df7":{"roots":{"references":[{"attributes":{"location":"top_left","plot":{"id":"e6a0aca4-fab5-451c-9685-7dea23dfdb33","subtype":"Chart","type":"Plot"}},"id":"a2ec3fa9-eb4d-4f2d-8d90-3db961ce0888","type":"Legend"},{"attributes":{"callback":null,"column_names":["width","fill_alpha","y","color","height","label","line_alpha","x","line_color"],"data":{"chart_index":["(17.3, 18.0]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[25.0],"label":["(17.3, 18.0]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.7520000000000024],"x":["17.65"],"y":[12.5]}},"id":"de40f77f-7f9c-466c-85a2-2b5cd6ba696d","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"79305c97-c685-4a1c-bf29-1e1204e06431","type":"Rect"},{"attributes":{"data_source":{"id":"5cb43ab1-b3b4-4404-ab03-651a5da1502c","type":"ColumnDataSource"},"glyph":{"id":"12bdf2ed-5ce5-4435-b0cc-e4a862a6e029","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"efe6ad64-8814-4ba7-8550-9b526503a76b","type":"GlyphRenderer"},{"attributes":{},"id":"a53ad505-5a5b-49b7-a6b5-6181df8e7e98","type":"BasicTicker"},{"attributes":{"callback":null,"end":236.90034090909091,"start":39.11329545454546},"id":"328862e7-b61c-4e7a-86cf-500dc35cec3e","type":"Range1d"},{"attributes":{"data_source":{"id":"dc523d5b-3509-4fa8-8922-a9abf4f1b645","type":"ColumnDataSource"},"glyph":{"id":"79583465-6867-4c12-8028-64031367642a","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"94bb54af-db32-4ece-bad1-bdd529212775","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["width","fill_alpha","y","color","height","label","line_alpha","x","line_color"],"data":{"chart_index":["(96.7, 103.3]"],"color":["#f22c40"],"fill_alpha":[0.6],"height":[2.0],"label":["(96.7, 103.3]"],"line_alpha":[1.0],"line_color":["black"],"width":[6.666666666666657],"x":["100.0"],"y":[1.0]}},"id":"aa8ca928-c9ad-4e3c-93bd-b0595d504577","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["width","fill_alpha","y","color","height","label","line_alpha","x","line_color"],"data":{"chart_index":["(59.1, 72.3]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[67.0],"label":["(59.1, 72.3]"],"line_alpha":[1.0],"line_color":["black"],"width":[13.142857142857139],"x":["65.7"],"y":[33.5]}},"id":"999a37e8-3a9e-4bde-8c55-37b84d384202","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"72e851d6-38cc-4d9d-98b4-f2025e8fe984","type":"Rect"},{"attributes":{"data_source":{"id":"522b8b2b-82ee-41d3-b398-9e9eadb3a5ef","type":"ColumnDataSource"},"glyph":{"id":"e6544d39-a286-47c8-85cb-64fe1c11c500","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"71dde442-0d8d-4b05-a467-e170c6bb87b7","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["width","fill_alpha","y","color","height","label","line_alpha","x","line_color"],"data":{"chart_index":["(42.1, 42.8]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"label":["(42.1, 42.8]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.7520000000000024],"x":["42.45"],"y":[0.0]}},"id":"636c38bc-9845-4963-badb-76ec3a2bfab1","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"c674e1cb-f479-41d5-bbf2-484bfeb8e771","type":"ColumnDataSource"},"glyph":{"id":"19f8199f-bdf5-4025-bfef-c40a50c2fed9","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"0af9a011-2543-4856-a52d-7e50e6fd0a98","type":"GlyphRenderer"},{"attributes":{" ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[16]</strong>&gt;</code></p>
